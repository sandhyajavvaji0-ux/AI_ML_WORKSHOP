# %%
bank=input("enter your bank name")
name = input("enter your name:")
age = int(input("enter your age:"))
balance = float(input("enter your balance"))
print("\n---welcome message----")
print(f"hiii..{name}!")
print(f"age:{age}")
print(f"your account balance is:{balance}")
print(f"welcome to {bank}")
# Out:
# ---welcome message----
# hiii..sandy!
# age:23
# your account balance is:5000.0
# welcome to sbi

# %%
savings_account,salary_account =input("enter number of saving_account and salary_account:").split()
print("number of savings_account:",savings_account)
print("number of salary_account:",salary_account)
# Out:
# number of savings_account: 300
# number of salary_account: 500
